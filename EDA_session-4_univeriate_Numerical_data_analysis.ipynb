# %% [markdown]
# ##### import all pakages
# #### read the data

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# $prevailing$-$wage$

# %%
p_wage=visa_df[['prevailing_wage']]        # datafreame [[]]
p_wage.head()
# Out:
#    prevailing_wage
# 0         592.2029
# 1       83425.6500
# 2      122996.8600
# 3       83434.0300
# 4      149907.3900

# %%
- count
- max
- min 
- mean
- median
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 - count
#       2 - max
#       3 - min
#
# NameError: name 'count' is not defined

# %%
p_wage=visa_df['prevailing_wage'] ############ series 
p_wage.count()
# Out:
# 25480

# %%
p_wage=visa_df['prevailing_wage']
wage_count=round(p_wage.count(),2)
wage_mean=round(p_wage.mean(),2)
wage_median=round(p_wage.median(),2)
wage_max=round(p_wage.max(),2)
wage_min=round(p_wage.min(),2)

print(wage_count)
print(wage_mean)
print(wage_median)
print(wage_max)
print(wage_min)

list1=[wage_count,wage_mean,wage_median,wage_max,wage_min]
index_list=['count','mean','median','max','min']
pd.DataFrame(list1,
             columns=['prevailing_wage'],
             index=index_list)
# Out:
# 25480
# 74455.81
# 70308.21
# 319210.27
# 2.14
#         prevailing_wage
# count          25480.00
# mean           74455.81
# median         70308.21
# max           319210.27
# min                2.14

# %%
# Numerical columns seperatly we have to need to know

num_cols=visa_df.select_dtypes(exclude='object').columns
dict1={}
for i in num_cols:
    print(i)
    count=visa_df[i].count()
    mean=round(p_wage.mean(),2)
    median=round(p_wage.median(),2)
    maxx=round(p_wage.max(),2)
    minn=round(p_wage.min(),2)
    list1=[count,mean,median,maxx,minn]
    dict1[i]=list1
index_list=['count','mean','median','max','min']
numer_df=pd.DataFrame(dict1,index=index_list)
numer_df.to_csv("numer_df.csv",index=False)
numer_df
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# mean           74455.81     74455.81         74455.81
# median         70308.21     70308.21         70308.21
# max           319210.27    319210.27        319210.27
# min                2.14         2.14             2.14

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
# wage_mean = round(p_wage.mean(),2)==== pandas

p_wage=visa_df['prevailing_wage']
np.mean(p_wage)
np.median(p_wage)
np.max(p_wage)
np.min(p_wage)
np.std(p_wage)
# Out:
# 52814.90589711402

# %% [markdown]
# **percentile-quantile**
#
# - In the numpy package we have np.percentile() and np.quantile()
# - percentile : if u want to 25p to
# - quantile: q1=25p(0.25)         q2=50p            q3=75p
# - Assume thet a student got 120 marks 95p
# - 95% of student has marks below 120

# %%
np.percentile(p_wage,25)
# Out:
# 34015.479999999996

# %%
np.quantile(p_wage,0.25)
# Out:
# 34015.479999999996

# %%
p_wage=visa_df['prevailing_wage']
wage_count=round(p_wage.count(),2)
wage_mean=round(p_wage.mean(),2)
wage_median=round(p_wage.median(),2)
wage_max=round(p_wage.max(),2)
wage_min=round(p_wage.min(),2)
wage_std=round(p_wage.std(),2)
##########################   numpy     ###############################
wage_25=round(np.percentile(p_wage,25),2)
wage_50=round(np.percentile(p_wage,50),2)
wage_75=round(np.percentile(p_wage,75),2)


list1=[wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std,wage_25,wage_50,wage_75]
index_list=['count','mean','median','max','min','std','25%','50%','75%']
pd.DataFrame(list1,
             columns=['prevailing_wage'],
             index=index_list)
# Out:
#         prevailing_wage
# count          25480.00
# mean           74455.81
# median         70308.21
# max           319210.27
# min                2.14
# std            52815.94
# 25%            34015.48
# 50%            70308.21
# 75%           107735.51

# %%
num_cols=visa_df.select_dtypes(exclude='object').columns
dict1={}
for i in num_cols:
    print(i)
    count=visa_df[i].count()
    mean=round(p_wage.mean(),2)
    median=round(p_wage.median(),2)
    maxx=round(p_wage.max(),2)
    minn=round(p_wage.min(),2)
    std=round(p_wage.std(),2)
    p25=round(np.percentile(visa_df[i],25),2)
    p50=round(np.percentile(visa_df[i],50),2)
    p75=round(np.percentile(visa_df[i],75),2)

    list1=[count,mean,median,maxx,minn,std,p25,p50,p75]
    dict1[i]=list1
index_list=['count','mean','median','max','min','std','25%','50%','75%']
numer_df=pd.DataFrame(dict1,index=index_list)
numer_df.to_csv("numer_df.csv",index=False)
numer_df
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# mean           74455.81     74455.81         74455.81
# median         70308.21     70308.21         70308.21
# max           319210.27    319210.27        319210.27
# min                2.14         2.14             2.14
# std            52815.94     52815.94         52815.94
# 25%             1022.00      1976.00         34015.48
# 50%             2109.00      1997.00         70308.21
# 75%             3504.00      2005.00        107735.51

# %%
# # p_wage = 25p= 34015   
# #total no = 25480

25*(25480)/100

# 25p= 6370 emp has wages less than 34015
# Out:
# 6370.0

# %%
p_wage=visa_df['prevailing_wage']
p_wage[p_wage<34015]
# Out:
# 0          592.2029
# 7          418.2298
# 12       28663.0500
# 16        3706.7900
# 17       16132.6100
#             ...
# 25461       54.9196
# 25465      481.2238
# 25466     6973.4000
# 25470      516.4101
# 25473    22845.5600
# Name: prevailing_wage, Length: 6370, dtype: float64

# %%
p_wage=visa_df['prevailing_wage']
count_25p=len(p_wage[p_wage<np.percentile(p_wage,25)])
count_50p=len(p_wage[p_wage<np.percentile(p_wage,50)])
count_75p=len(p_wage[p_wage<np.percentile(p_wage,75)])

l1=['count of 25%','count of 50%','count of 75%']
l2=[count_25p,count_50p,count_75p]
d1=pd.DataFrame(zip(l1,l2),columns=['Till per','Count'])
print(d1)
plt.bar(x=d1['Till per'], height=d1['Count'])
plt.show()
# Out:
#        Till per  Count
# 0  count of 25%   6370
# 1  count of 50%  12740
# 2  count of 75%  19110

# %%
# You want to extract a dataframe 
# which has wage less than 34015 (25p)

# 100   25min    34k

# %%
# step:1- take the reference column first 
# step:2- apply the condition 
#       it will provide True and False 
# step:3- Apply the original dataframe dataframe on top of that 
#            so that it will give only true values

p_wage=visa_df['prevailing_wage']
p_25=np.percentile(p_wage,25)
con=p_wage>p_25
visa_df[con]

visa_df[visa_df['prevailing_wage']<34015]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
p_wage=visa_df['prevailing_wage']
p_50=np.percentile(p_wage,50)
con=p_wage>p_50
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# 5                         N             2339         2012
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 1                Northeast         83425.65         Year                  Y
# 2                     West        122996.86         Year                  Y
# 3                     West         83434.03         Year                  Y
# 4                    South        149907.39         Year                  Y
# 5                    South         78252.14         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South         77092.57         Year                  Y
# 25476            Northeast        279174.79         Year                  Y
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# 5       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [12740 rows x 12 columns]

# %%
# # bet 25p to 50p
# # bet 34k to 70k
# # >25  and <50p


p_wage=visa_df['prevailing_wage']
p_25=np.percentile(p_wage,25)
p_50=np.percentile(p_wage,50)

# # bet 25p to 50p
con1=p_wage<p_25
con2=p_wage<p_50

visa_df[con1&con2]


#visa_df[(visa_df['prevailing_wage']>34015)&(visa_df['prevailing_wage']>70000)]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 7                         N             3035         1924
# 12                        N           123876         1963
# 16                        N            76638         1991
# 17                        N             2747         2001
# ...                     ...              ...          ...
# 25461                     N             2861         2004
# 25465                     N             2577         1995
# 25466                     N             1938         2005
# 25470                     N             2272         1970
# 25473                     N             2421         2007
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# 16                 Midwest        3706.7900         Year                  Y
# 17                    West       16132.6100         Year                  Y
# ...                    ...              ...          ...                ...
# 25461                 West          54.9196         Hour                  Y
# 25465                South         481.2238         Hour                  Y
# 25466                 West        6973.4000         Year                  Y
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
#
#       case_status
# 0          Denied
# 7          Denied
# 12      Certified
# 16      Certified
# 17      Certified
# ...           ...
# 25461      Denied
# 25465   Certified
# 25466      Denied
# 25470   Certified
# 25473   Certified
#
# [6370 rows x 12 columns]

# %%
# <25p    >75p
p_wage=visa_df['prevailing_wage']
p_25=np.percentile(p_wage,25)
p_75=np.percentile(p_wage,75)

# <25p    >75p
con1=p_wage<p_25
con2=p_wage>p_75

visa_df[con1 | con2]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 2         EZYV03           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 2                         Y            44444         2008
# 4                         N             1082         2005
# 7                         N             3035         1924
# 12                        N           123876         1963
# ...                     ...              ...          ...
# 25469                     N             2261         1997
# 25470                     N             2272         1970
# 25473                     N             2421         2007
# 25476                     N             3274         2006
# 25477                     N             1121         1910
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 2                     West      122996.8600         Year                  Y
# 4                    South      149907.3900         Year                  Y
# 7                     West         418.2298         Hour                  Y
# 12               Northeast       28663.0500         Year                  Y
# ...                    ...              ...          ...                ...
# 25469            Northeast      273772.4700         Year                  N
# 25470            Northeast         516.4101         Hour                  Y
# 25473            Northeast       22845.5600         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
#
#       case_status
# 0          Denied
# 2          Denied
# 4       Certified
# 7          Denied
# 12      Certified
# ...           ...
# 25469   Certified
# 25470   Certified
# 25473   Certified
# 25476   Certified
# 25477   Certified
#
# [12740 rows x 12 columns]

# %%
# good at writing quires

# %% [markdown]
# # $Histogram$

# %% [markdown]
# - From raw data will make class intervals
# - will count the obs in each class intervals
# - Frequency distribution table
# - Plot of frequrency distribution table is histogramm

# %%
p_wage=visa_df['prevailing_wage']
freq,interval,n=plt.hist(p_wage,bins=40)
freq , interval
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]))

# %%
2.13670000e+00,
7.98234003e+03,
# Out:
# (7982.34003,)

# %%
# 2.13  to 7982.34

p_wage=visa_df['prevailing_wage']
con1=p_wage>2.13
con2=p_wage<7982.3400

len(visa_df[con1&con2])
# Out:
# 2992

# %%
7.98234003e+03
1.59625434e+04
# Out:
# 15962.5434

# %%
p_wage=visa_df['prevailing_wage']
con1=p_wage>7.98234003e+03
con2=p_wage<1.59625434e+04

len(visa_df[con1&con2])
# Out:
# 871

# %%
interval
# Out:
# array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#        3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#        6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#        9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#        1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#        1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#        1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#        2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#        2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#        2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#        3.19210270e+05])

# %%
freq
# Out:
# array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#        1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#         509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#          79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#           7.,    3.,    6.,    5.])

# %%
# create the table for above this 
# interval                          count 


p_wage=visa_df['prevailing_wage']

# %%
pd.DataFrame(freq)
# Out:
#          0
# 0   2992.0
# 1    871.0
# 2   1005.0
# 3   1170.0
# 4   1242.0
# 5   1434.0
# 6   1385.0
# 7   1443.0
# 8   1444.0
# 9   1445.0
# 10  1457.0
# 11  1335.0
# 12  1268.0
# 13  1217.0
# 14  1088.0
# 15   978.0
# 16   807.0
# 17   645.0
# 18   509.0
# 19   373.0
# 20   264.0
# 21   144.0
# 22   105.0
# 23   111.0
# 24   107.0
# 25    99.0
# 26    88.0
# 27    79.0
# 28    65.0
# 29    64.0
# 30    58.0
# 31    53.0
# 32    33.0
# 33    33.0
# 34    29.0
# 35    19.0
# 36     7.0
# 37     3.0
# 38     6.0
# 39     5.0

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
plt.hist(p_wage)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(visa_df['prevailing_wage'],bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]),
#  <BarContainer object of 40 artists>)

# %%
sns.displot(visa_df['prevailing_wage'],bins=40)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage'])

# histogram

################################################################################################################

sns.displot(visa_df['prevailing_wage'],kind='ecdf')

# ecdf = comulative distribution plot

#################################################################################################################

sns.displot(visa_df['prevailing_wage'],kind='kde')

# kde = kernal density estimation 

###############################################################################################################
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - 1. histogram
# - 2. ecdf = comulative distribution plot
# - 3. kde = kernal density estimation

# %% [markdown]
# subplot is not working for sns.displot or seaborn

# %%
# plt.subplot(1,2,1)         ### 1 -row ; 2 -columns

plt.subplot(1,3,1)   ### 1 -row ; 3- -columnn
plt.hist(visa_df['prevailing_wage'])
plt.subplot(1,3,2)
plt.hist(visa_df['prevailing_wage'])
plt.subplot(1,3,3)   
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)
