# %% [markdown]
# - It is very very imp to convrt categorical data to numerical data
#
# - Bcz all ML models developed by using mathematics
#
# - If u try to implement ML algorithm developement using Cat columns it will fail
#
# -Methods :
#
#     - Manuallay by using map method
#
#     - One hot encoder : pd.get_dummies
#
#     - Label encode : Sicket

# %%
# import the reqired packages 

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data

df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## map

# %% [markdown]
# - first consider one categoricl column
#
# - observe how many unique labels are there
#
# - Assume here we are taking case_status column
#
# - case_status two unique labels are there :
#
#     - Denied
#
#     - Certified
#
# - Create a dict by providing key:value
#
# - Here the kay= denied  and the value =1
#
# - key=Certified  and the value = 0
#
# - dict will looks like : {'Certified':0,'Denied':1}

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d1={'Certified':0,'Denied':1}
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
# convert into numerical by map method

d1={'Certified':0,'Denied':1}
visa_df['case_status'].map(d1)


# after mapping , in which column you want apply the data 
# you want to crete a new columns
# you want to use a old columns
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df['case_status']=visa_df['case_status'].map(d1)

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            1
# ...

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d1={}
labels=visa_df['continent'].unique()
for i in range (len(labels)):
    d1[labels[i]]=i
    
visa_df['continent']=visa_df['continent'].map(d1)
visa_df.head()
# Out:
#   case_id  continent education_of_employee has_job_experience  \
# 0  EZYV01          0           High School                  N
# 1  EZYV02          0              Master's                  Y
# 2  EZYV03          0            Bachelor's                  N
# 3  EZYV04          0            Bachelor's                  N
# 4  EZYV05          1              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# ## Method 2

# %% [markdown]
# ## $np.where$

# %%
# Read the data again

df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - np.where is a kind of if-else
#
# - np.where is useful for binary condition
#
# - which means it is useful for the columns having two labels
#
# - np.where will take 3 parameter
#
#     - condition
#
#     - True values
#
#     - False values
#
# - I want to replace case status column with 1 when it is Denied
#
# - otherwise it is zero
#
# - con=visadf['case_status']=='Denied'
#
# - True value =1   False value = 0
#
# -np.where(con, , )

# %%
con=visa_df['case_status']=='Denied'
visa_df['case_status']=np.where(con,1,0)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            1
# ...

# %% [markdown]
# # Method-3
#
# ## $one$-$hot$-$encoder$
#
# **pd.getdummies**

# %% [markdown]
# - one hot encoder means at a time only one will be ON,Other is OFF
#
# - ON represent with one , and OFF represent with zero
#
# - One hot encoder creates new extra columns based on labels in the column
#
# - for example case_status has two unique labels
#
# - if u apply one hot encoder on case_status it creates two extra columns
#
#    - case_status_Denied
#
#    - case_status_Certified
#
# ---------
# |Case status||case_status_Denied||case_status_Certified|
# |-----------||------------------||---------------------|
# |Denied     ||       1          ||          0          |
# |Certified  ||       0          ||          1         |

# %%
**Advantage**

- One hot encoder gives independense between the variables 

- It is one of the imporantt property before apply models

- Variables are independent of each other

- Variables are perpendicular of each other

- Variables are orthogonal of each other

- Variables are 90degrees phase shift

**Disadvantage**

- Assume that a columns that 100 unique labels

- if we apply one hot encoder it will create 100 new columns 

- your data matrix become sparse 

- we required more time and more memory

# %%
# Read the data again

df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df

# drop the ID before apply one hot encoder 
visa_df.drop('case_id',axis=1,inplace=True)

#apply one hot encoder 
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# # Method-4
#
# ## $Label$-$Encoder$

# %% [markdown]
# - we already implementeed map method by our own
#
# - The same map method implemented as python package way
#
# - **Package name : sklearn**
#
# - **Method name  : LabelEncoder**
#
# - Sklearn package approach is very easy
#
#     - Step-1 : Read the Package---- (from sklearn.preprocessing import LabelEncoder)
#
#     - Step-2 : Save the Package----(le=LabelEncoder())
#
#     - Step-3 : Apply fit transform--(le.fit_transform(visa_df['continent']))

# %%
#read data
df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df
print(visa_df['continent'].values[:10])

# Read the Package
from sklearn.preprocessing import LabelEncoder

# Save the Package
le=LabelEncoder()

# Apply fit transform
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df.head()
# Out:
# ['Asia' 'Asia' 'Asia' 'Asia' 'Africa' 'Asia' 'Asia' 'North America' 'Asia'
#  'Europe']
#   case_id  continent education_of_employee has_job_experience  \
# 0  EZYV01          1           High School                  N
# 1  EZYV02          1              Master's                  Y
# 2  EZYV03          1            Bachelor's                  N
# 3  EZYV04          1            Bachelor's                  N
# 4  EZYV05          0              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
# ...

# %%
#read data
df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df
print(visa_df['case_status'].values[:10])

# Read the Package
from sklearn.preprocessing import LabelEncoder

# Save the Package
le=LabelEncoder()

# Apply fit transform
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df.head()
# Out:
# ['Denied' 'Certified' 'Denied' 'Denied' 'Certified' 'Certified'
#  'Certified' 'Denied' 'Certified' 'Certified']
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
# ...

# %% [markdown]
# ### we cant directly pass the data
# ### do with loop

# %%
#read data
df1="C:\\Users\\admin\\OneDrive\\PRATIK\\NARESH IT\\DATA SCIENCE\\DATA SETS\\csv\\Visadataset.csv"
visa_df=pd.read_csv(df1)
visa_df


# Read the Package
from sklearn.preprocessing import LabelEncoder

# Save the Package
le=LabelEncoder()

# Apply fit transform
# we cant directly apply for all the data 
# do with loop

cat_cols=visa_df.select_dtypes(include='object').columns

for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
    
visa_df.head()
# Out:
#    case_id  continent  education_of_employee  has_job_experience  \
# 0        0          1                      2                   0
# 1        1          1                      3                   1
# 2        2          1                      0                   0
# 3        3          1                      0                   0
# 4        4          0                      3                   1
#
#    requires_job_training  no_of_employees  yr_of_estab  region_of_employment  \
# 0                      0            14513         2007                     4
# 1                      0             2412         2002                     2
# 2                      1            44444         2008                     4
# 3                      0               98         1897                     4
# 4                      0             1082         2005                     3
#
#    prevailing_wage  unit_of_wage  full_time_position  case_status
# ...

# %% [markdown]
# ## **inverse transform**

# %%
print(visa_df['case_status'][:5])  # transformed one 

# we are trying to check what is 1 and 0
# le is LabelEncoder we already defined it 

le.inverse_transform(visa_df['case_status'])[:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: case_status, dtype: int32
# array(['Denied', 'Certified', 'Denied', 'Denied', 'Certified'],
#       dtype=object)

# %% [markdown]
# # 4 Methods
#
# - ## Method-1 : Map
#
# - ## Method-2 : np.where
#
# - ## Method-3 : one hot encoder      ---- pd.getdummies()
#
# - ## Method-4 : LabelEncoder      ------- from sklearn
